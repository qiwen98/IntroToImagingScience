# %%
#get the camera projection matrix, from camera to world
import cv2
import numpy as np
import matplotlib.pyplot as plt
import os
import glob

# Define checkerboard size (number of inner corners per row and column)
CHECKERBOARD = (17, 24)  # Example: 9x6 inner corners

objp = np.zeros((17*24,3), np.float32)
objp[:,:2] = np.mgrid[0:17,0:24].T.reshape(-1,2)
# Arrays to store object points and image points from all the images.
objpoints = [] # 3d point in real world space
imgpoints = [] # 2d points in image plane.

# Directory containing the checkerboard images
DATA_DIR = "Data/Calibration/NoPattern"
image_files = sorted(glob.glob(os.path.join(DATA_DIR, "*.png")))  # Adjust extension if needed

# Function to detect and plot corners
def detect_and_plot_corners(image_path, plot_title, save_path=None):
    # Load image
    img = cv2.imread(image_path)
    if img is None:
        print(f"Failed to load image: {image_path}")
        return False, None, img
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

    # Detect checkerboard corners
    ret, corners=cv2.findChessboardCornersSB(gray, CHECKERBOARD, cv2.CALIB_CB_NORMALIZE_IMAGE,cv2.CALIB_CB_EXHAUSTIVE)

    if ret:
        print("ret found")
        objpoints.append(objp)
        # Refine corner positions
        corners = cv2.cornerSubPix(gray, corners, (11, 11), (-1, -1), 
            criteria = (cv2.TERM_CRITERIA_EPS + cv2.TERM_CRITERIA_MAX_ITER, 30000, 0.0001))
        print(corners.shape)
        imgpoints.append(corners)
        # Draw corners on image for visualization
        img_with_corners = img.copy()
        cv2.drawChessboardCorners(img_with_corners, CHECKERBOARD, corners, ret)

        # Plot corners in pixel coordinates
        plt.figure(figsize=(8, 6))
        plt.imshow(img, cmap='gray')
        corners = corners.squeeze()  # Shape: (N, 2)
        plt.scatter(corners[:, 0], corners[:, 1], c='red', s=50, label='Detected Corners')
        plt.title(plot_title)
        plt.xlabel('Pixel Column (x)')
        plt.ylabel('Pixel Row (y)')
        plt.legend()
        if save_path:
            plt.savefig(save_path)
            plt.close()
        else:
            plt.show()

        return True, corners, img_with_corners
    else:
        # Plot the image even if detection failed
        plt.figure(figsize=(8, 6))
        plt.imshow(img, cmap='gray')
        plt.title(f"{plot_title} (No Corners Detected)")
        plt.xlabel('Pixel Column (x)')
        plt.ylabel('Pixel Row (y)')
        if save_path:
            plt.savefig(save_path)
            plt.close()
        else:
            plt.show()
        return False, None, img

# Part a: Detect and plot corners for the first image
if image_files:
    print("Processing first image...")
    success, corners, _ = detect_and_plot_corners(
        image_files[0], 
        "Detected Corners in First Checkerboard Image"
    )
    if success:
        print("Corners successfully detected in the first image.")
    else:
        print("Failed to detect corners in the first image.")

# Part b: Detect corners in all 30 images and report failures
print("\nProcessing all images...")
failed_images = []
for i, img_path in enumerate(image_files[:30]):  # Limit to 30 images
    print(f"\nProcessing image {i+1}: {os.path.basename(img_path)}")
    save_path = f"output_image_{i+1}.png"
    success, corners, _ = detect_and_plot_corners(
        img_path, 
        f"Checkerboard Image {i+1}"
    )
    if not success:
        print(f"Failed to detect corners in image {i+1}: {os.path.basename(img_path)}")
        failed_images.append((i+1, img_path, save_path))
    else:
        print(f"Successfully detected {len(corners)} corners in image {i+1}.")

# Report summary
print("\nSummary:")
print(f"Processed {min(len(image_files), 30)} images.")
print(f"Number of images with failed corner detection: {len(failed_images)}")
if failed_images:
    print("Images with failed corner detection:")
    for idx, img_path, save_path in failed_images:
        print(f"Image {idx}: {os.path.basename(img_path)} (see {save_path})")
else:
    print("All corners successfully detected in all images.")

img = cv2.imread("Data/Calibration/NoPattern/1.png")
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
camera_width=img.shape[0]
camera_height=img.shape[1]
Number_of_Images=19
criteriaEnd = (cv2.TERM_CRITERIA_EPS + cv2.TERM_CRITERIA_MAX_ITER, 30000, 0.0001)  # Termination criteria for estimateCameraParams
reprojectionError1, C_K_intrinsic, dist_coeffs1, C_rvecs, C_tvecs = cv2.calibrateCamera(
    objpoints, imgpoints, (camera_width, camera_height), None, None,
    flags=cv2.CALIB_FIX_K4 + cv2.CALIB_FIX_K5 + cv2.CALIB_FIX_K6,criteria=criteriaEnd
)
print(reprojectionError1)


newcameramtx, roi = cv2.getOptimalNewCameraMatrix(C_K_intrinsic, 
                                                  dist_coeffs1, 
                                                  (camera_width,camera_height), 
                                                  1, 
                                                  (camera_width,camera_height)
                                                  )
# Out:
# Processing first image...
# ret found
# (408, 1, 2)
# Corners successfully detected in the first image.
#
# Processing all images...
#
# Processing image 1: 1.png
# ret found
# (408, 1, 2)
# Successfully detected 408 corners in image 1.
#
# Processing image 2: 10.png
# ret found
# (408, 1, 2)
# Successfully detected 408 corners in image 2.
#
# Processing image 3: 11.png
# ret found
# (408, 1, 2)
# Successfully detected 408 corners in image 3.
#
# Processing image 4: 12.png
# Failed to detect corners in image 4: 12.png
#
# Processing image 5: 13.png
# ret found
# (408, 1, 2)
# Successfully detected 408 corners in image 5.
#
# Processing image 6: 14.png
# ret found
# (408, 1, 2)
# Successfully detected 408 corners in image 6.
#
# Processing image 7: 15.png
# Failed to detect corners in image 7: 15.png
#
# Processing image 8: 16.png
# ret found
# (408, 1, 2)
# Successfully detected 408 corners in image 8.
#
# Processing image 9: 17.png
# ret found
# (408, 1, 2)
# Successfully detected 408 corners in image 9.
#
# Processing image 10: 18.png
# ret found
# (408, 1, 2)
# Successfully detected 408 corners in image 10.
#
# Processing image 11: 19.png
# Failed to detect corners in image 11: 19.png
#
# Processing image 12: 2.png
# ret found
# (408, 1, 2)
# Successfully detected 408 corners in image 12.
#
# Processing image 13: 20.png
# ret found
# (408, 1, 2)
# Successfully detected 408 corners in image 13.
#
# Processing image 14: 21.png
# ret found
# (408, 1, 2)
# Successfully detected 408 corners in image 14.
#
# Processing image 15: 22.png
# ret found
# (408, 1, 2)
# Successfully detected 408 corners in image 15.
#
# Processing image 16: 23.png
# ret found
# (408, 1, 2)
# Successfully detected 408 corners in image 16.
#
# Processing image 17: 24.png
# Failed to detect corners in image 17: 24.png
#
# Processing image 18: 25.png
# Failed to detect corners in image 18: 25.png
#
# Processing image 19: 26.png
# Failed to detect corners in image 19: 26.png
#
# Processing image 20: 27.png
# Failed to detect corners in image 20: 27.png
#
# Processing image 21: 28.png
# ret found
# (408, 1, 2)
# Successfully detected 408 corners in image 21.
#
# Processing image 22: 29.png
# Failed to detect corners in image 22: 29.png
#
# Processing image 23: 3.png
# Failed to detect corners in image 23: 3.png
#
# Processing image 24: 30.png
# ret found
# (408, 1, 2)
# Successfully detected 408 corners in image 24.
#
# Processing image 25: 4.png
# ret found
# (408, 1, 2)
# Successfully detected 408 corners in image 25.
#
# Processing image 26: 5.png
# ret found
# (408, 1, 2)
# Successfully detected 408 corners in image 26.
#
# Processing image 27: 6.png
# Failed to detect corners in image 27: 6.png
#
# Processing image 28: 7.png
# ret found
# (408, 1, 2)
# Successfully detected 408 corners in image 28.
#
# Processing image 29: 8.png
# ret found
# (408, 1, 2)
# Successfully detected 408 corners in image 29.
#
# Processing image 30: 9.png
# Failed to detect corners in image 30: 9.png
#
# Summary:
# Processed 30 images.
# Number of images with failed corner detection: 11
# Images with failed corner detection:
# Image 4: 12.png (see output_image_4.png)
# Image 7: 15.png (see output_image_7.png)
# Image 11: 19.png (see output_image_11.png)
# Image 17: 24.png (see output_image_17.png)
# Image 18: 25.png (see output_image_18.png)
# Image 19: 26.png (see output_image_19.png)
# Image 20: 27.png (see output_image_20.png)
# Image 22: 29.png (see output_image_22.png)
# Image 23: 3.png (see output_image_23.png)
# Image 27: 6.png (see output_image_27.png)
# Image 30: 9.png (see output_image_30.png)
# 0.11301917717200992

# %%
newcameramtx, roi = cv2.getOptimalNewCameraMatrix(C_K_intrinsic, 
                                                  dist_coeffs1, 
                                                  (camera_width,camera_height), 
                                                  1, 
                                                  (camera_width,camera_height)
                                                  )

# %% [markdown]
# Calibrate projector

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
from scipy.ndimage import map_coordinates

# Projector resolution
PROJ_COLS = 3840  # Columns
PROJ_ROWS = 2160  # Rows

# Phase ranges
HORIZ_PHASE_RANGE = 2 * np.pi  # [0, 2π] for horizontal (columns)
VERT_PHASE_RANGE = 1.125 * np.pi  # [0, 1.125π] for vertical (rows)

# Checkerboard size (inner corners, adjust as needed)
CHECKERBOARD = (17, 24)

# Checkerboard square size (in mm, adjust as needed)
SQUARE_SIZE = 15.0  # mm

def compute_phase_map(I0, I1, I2, I3):
    """
    Compute phase map using four-phase shift algorithm.
    I0, I1, I2, I3: Grayscale images with phase shifts 0, π/2, π, 3π/2.
    Returns: Phase map in radians.
    """
    I0 = I0.astype(float)
    I1 = I1.astype(float)
    I2 = I2.astype(float)
    I3 = I3.astype(float)
    
    numerator = I3 - I1
    denominator = I0 - I2
    phase = np.arctan2(numerator, denominator)  # Phase in [-π, π]
    phase = np.where(phase < 0, phase + 2 * np.pi, phase)  # [0, 2π]
    return phase

def load_phase_images(base_path, pos_num="pos1"):
    """
    Load eight phase-shifted images: 1-4 (horizontal), 5-8 (vertical).
    base_path: Directory path (e.g., 'Data/Calibration/NoPattern').
    Returns: Two tuples of four grayscale images (horizontal: I0-I3, vertical: I0-I3).
    """
    h_I0 = cv2.imread(f"{base_path}/{pos_num}_1.png", cv2.IMREAD_GRAYSCALE)
    h_I1 = cv2.imread(f"{base_path}/{pos_num}_2.png", cv2.IMREAD_GRAYSCALE)
    h_I2 = cv2.imread(f"{base_path}/{pos_num}_3.png", cv2.IMREAD_GRAYSCALE)
    h_I3 = cv2.imread(f"{base_path}/{pos_num}_4.png", cv2.IMREAD_GRAYSCALE)
    
    v_I0 = cv2.imread(f"{base_path}/{pos_num}_5.png", cv2.IMREAD_GRAYSCALE)
    v_I1 = cv2.imread(f"{base_path}/{pos_num}_6.png", cv2.IMREAD_GRAYSCALE)
    v_I2 = cv2.imread(f"{base_path}/{pos_num}_7.png", cv2.IMREAD_GRAYSCALE)
    v_I3 = cv2.imread(f"{base_path}/{pos_num}_8.png", cv2.IMREAD_GRAYSCALE)
    
    if any(img is None for img in [h_I0, h_I1, h_I2, h_I3, v_I0, v_I1, v_I2, v_I3]):
        raise FileNotFoundError(f"Failed to load phase images from {base_path}")
    
    return (h_I0, h_I1, h_I2, h_I3), (v_I0, v_I1, v_I2, v_I3)

def phase_to_projector_coords(phase_h, phase_v):
    """
    Convert phase values to projector coordinates.
unionizer.
    phase_h: Horizontal phase map [0, 2π].
    phase_v: Vertical phase map [0, 1.125π].
    Returns: Projector columns [0, 3840], rows [0, 2160].
    """
    proj_cols = (phase_h / HORIZ_PHASE_RANGE) * PROJ_COLS  # [0, 3840]
    proj_rows = (phase_v / VERT_PHASE_RANGE) * PROJ_ROWS  # [0, 2160]
    return proj_cols, proj_rows

def shift_phase_jump(phase_map, offset):
    """Shift phase jump by adding offset and rewrapping."""
    return np.angle(np.exp(1j * (phase_map + offset)))

def get_checkerboard_world_points(checkerboard, square_size):
    """
    Generate 3D world points for checkerboard corners.
    checkerboard: Tuple (rows, cols) of inner corners.
    square_size: Size of each square in mm.
    Returns: Array of shape (N, 3) with (X, Y, Z) coordinates (Z=0).
    """
    rows, cols = checkerboard
    objp = np.zeros((rows * cols, 3), np.float32)
    objp[:, :2] = np.mgrid[0:rows, 0:cols].T.reshape(-1, 2) * square_size
    return objp

def find_projector_pixels(corners, phase_h, phase_v, use_interpolation=True):
    """Map camera coordinates to projector coordinates using phase maps."""
    corners = np.asarray(corners, dtype=np.float32)
    if len(corners.shape) != 3 or corners.shape[1] != 1 or corners.shape[2] != 2:
        raise ValueError(f"Expected corners shape (N, 1, 2), got {corners.shape}")
    
    corners_2d = corners.squeeze(axis=1)
    corner_phases_h = np.zeros(len(corners_2d), dtype=np.float32)
    corner_phases_v = np.zeros(len(corners_2d), dtype=np.float32)
    
    if use_interpolation:
        for i, corner in enumerate(corners_2d):
            x, y = corner  # Subpixel coordinates
            # Use bilinear interpolation to get phase values
            corner_phases_h[i] = map_coordinates(phase_h, [[y], [x]], order=1, mode='nearest')
            corner_phases_v[i] = map_coordinates(phase_v, [[y], [x]], order=1, mode='nearest')
    else:
        for i, corner in enumerate(corners_2d):
            x, y = int(corner[0]), int(corner[1])
            corner_phases_h[i] = phase_h[y, x]
            corner_phases_v[i] = phase_v[y, x]
    
    proj_cols = (corner_phases_h / HORIZ_PHASE_RANGE) * PROJ_COLS
    proj_rows = (corner_phases_v / VERT_PHASE_RANGE) * PROJ_ROWS
    proj_pixels = np.stack((proj_cols, proj_rows), axis=-1).reshape(-1, 1, 2)
    return proj_pixels

def process_pose(pose_num, base_path_no_pattern, base_path_pattern, camera_matrix, dist_coeffs, newcameramtx):
    """
    Process a single checkerboard pose to find camera-projector correspondences.
    Returns: Object points (3D), camera points (2D), projector points (2D).
    """
    # Load checkerboard image
    checker_img = cv2.imread(f"{base_path_no_pattern}/{pose_num}.png")
    if checker_img is None:
        raise FileNotFoundError(f"Checkerboard image {pose_num}.png not found")
    
    # Undistort checkerboard image
    checker_undist = cv2.undistort(checker_img, camera_matrix, dist_coeffs, None, newcameramtx)
    gray_undist = cv2.cvtColor(checker_undist, cv2.COLOR_BGR2GRAY)
    
    # Detect checkerboard corners
    ret, corners = cv2.findChessboardCornersSB(
        gray_undist, CHECKERBOARD,
        flags=cv2.CALIB_CB_NORMALIZE_IMAGE | cv2.CALIB_CB_EXHAUSTIVE
    )
    if not ret:
        raise ValueError(f"Checkerboard corners not detected for pose {pose_num}")
    
    # Refine corners
    criteria = (cv2.TERM_CRITERIA_EPS + cv2.TERM_CRITERIA_MAX_ITER, 30, 0.0001)
    corners = cv2.cornerSubPix(gray_undist, corners, (11, 11), (-1, -1), criteria)
    # corners is already in shape (N, 1, 2)
    
    # Load phase-shifted images
    (h_I0, h_I1, h_I2, h_I3), (v_I0, v_I1, v_I2, v_I3) = load_phase_images(base_path_pattern, pos_num=f"pos{pose_num}")
    
    # Undistort phase images
    h_I0 = cv2.undistort(h_I0, camera_matrix, dist_coeffs, None, newcameramtx)
    h_I1 = cv2.undistort(h_I1, camera_matrix, dist_coeffs, None, newcameramtx)
    h_I2 = cv2.undistort(h_I2, camera_matrix, dist_coeffs, None, newcameramtx)
    h_I3 = cv2.undistort(h_I3, camera_matrix, dist_coeffs, None, newcameramtx)
    v_I0 = cv2.undistort(v_I0, camera_matrix, dist_coeffs, None, newcameramtx)
    v_I1 = cv2.undistort(v_I1, camera_matrix, dist_coeffs, None, newcameramtx)
    v_I2 = cv2.undistort(v_I2, camera_matrix, dist_coeffs, None, newcameramtx)
    v_I3 = cv2.undistort(v_I3, camera_matrix, dist_coeffs, None, newcameramtx)
    
    # Compute phase maps
    phase_h = compute_phase_map(h_I0, h_I1, h_I2, h_I3)
    phase_v = compute_phase_map(v_I0, v_I1, v_I2, v_I3)
    
    # Apply phase shift (adjust offsets as needed)
    h_offset = -1.6  # Adjust based on phase map inspection
    v_offset = -1.8
    new_horizontal_phase = shift_phase_jump(phase_h, h_offset)
    new_vertical_phase = shift_phase_jump(phase_v, v_offset)
    
    # Validate phase ranges
    if np.max(new_horizontal_phase) > HORIZ_PHASE_RANGE or np.min(new_horizontal_phase) < 0:
        print(f"Warning: Horizontal phase out of expected range for pose {pose_num}")
    if np.max(new_vertical_phase) > VERT_PHASE_RANGE or np.min(new_vertical_phase) < 0:
        print(f"Warning: Vertical phase out of expected range for pose {pose_num}")
    
    # Find projector pixels for checkerboard corners
    proj_points = find_projector_pixels(corners, new_horizontal_phase, new_vertical_phase)
    
    # Generate 3D world points
    obj_points = get_checkerboard_world_points(CHECKERBOARD, SQUARE_SIZE)
    
    return obj_points, corners, proj_points

def main():
    # Base paths (adjust as needed)
    base_path_no_pattern = "Data/Calibration/NoPattern"
    base_path_pattern = "Data/Calibration/Patterns"
    
    # Process multiple poses
    num_poses = 30  # Adjust based on number of checkerboard poses
    all_obj_points = []
    all_cam_points = []
    all_proj_points = []
    
    for pose_num in range(1, num_poses + 1):
        try:
            obj_points, cam_points, proj_points = process_pose(
                pose_num, base_path_no_pattern, base_path_pattern,
                C_K_intrinsic, dist_coeffs1, newcameramtx
            )
            all_obj_points.append(obj_points)
            all_cam_points.append(cam_points)
            all_proj_points.append(proj_points)
            print(f"Processed pose {pose_num}: {len(cam_points)} corners")
        except Exception as e:
            print(f"Error processing pose {pose_num}: {e}")
    
    # Print sample correspondences
    print("\nSample Camera-Projector Correspondences (Pose 1, first 5 corners):")
    for i in range(min(5, len(all_cam_points[0]))):
        cam_x, cam_y = all_cam_points[0][i, 0]  # Access (N, 1, 2) shape
        proj_col, proj_row = all_proj_points[0][i, 0]
        print(f"Corner {i}: Camera ({cam_x:.2f}, {cam_y:.2f}) -> Projector ({proj_col:.2f}, {proj_row:.2f})")
    
    # Return data for projector calibration
    return all_obj_points, all_cam_points, all_proj_points

if __name__ == "__main__":
    all_obj_points, all_cam_points, all_proj_points = main()
# Out:
# Warning: Horizontal phase out of expected range for pose 1
# Warning: Vertical phase out of expected range for pose 1
# Processed pose 1: 408 corners
# /var/folders/6q/b1f95jp528qg7gf5zww7z9h80000gn/T/ipykernel_15997/1026201495.py:100: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   corner_phases_h[i] = map_coordinates(phase_h, [[y], [x]], order=1, mode='nearest')
# /var/folders/6q/b1f95jp528qg7gf5zww7z9h80000gn/T/ipykernel_15997/1026201495.py:101: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   corner_phases_v[i] = map_coordinates(phase_v, [[y], [x]], order=1, mode='nearest')
# Error processing pose 2: Checkerboard corners not detected for pose 2
# Error processing pose 3: Checkerboard corners not detected for pose 3
# Warning: Horizontal phase out of expected range for pose 4
# Warning: Vertical phase out of expected range for pose 4
# Processed pose 4: 408 corners
# Warning: Horizontal phase out of expected range for pose 5
# Warning: Vertical phase out of expected range for pose 5
# Processed pose 5: 408 corners
# Error processing pose 6: Checkerboard corners not detected for pose 6
# Warning: Horizontal phase out of expected range for pose 7
# Warning: Vertical phase out of expected range for pose 7
# Processed pose 7: 408 corners
# Warning: Horizontal phase out of expected range for pose 8
# Warning: Vertical phase out of expected range for pose 8
# Processed pose 8: 408 corners
# Warning: Horizontal phase out of expected range for pose 9
# Warning: Vertical phase out of expected range for pose 9
# Processed pose 9: 408 corners
# Warning: Horizontal phase out of expected range for pose 10
# Warning: Vertical phase out of expected range for pose 10
# Processed pose 10: 408 corners
# Warning: Horizontal phase out of expected range for pose 11
# Warning: Vertical phase out of expected range for pose 11
# Processed pose 11: 408 corners
# Error processing pose 12: Checkerboard corners not detected for pose 12
# Warning: Horizontal phase out of expected range for pose 13
# Warning: Vertical phase out of expected range for pose 13
# Processed pose 13: 408 corners
# Error processing pose 14: Checkerboard corners not detected for pose 14
# Error processing pose 15: Checkerboard corners not detected for pose 15
# Warning: Horizontal phase out of expected range for pose 16
# Warning: Vertical phase out of expected range for pose 16
# Processed pose 16: 408 corners
# Warning: Horizontal phase out of expected range for pose 17
# Warning: Vertical phase out of expected range for pose 17
# Processed pose 17: 408 corners
# Warning: Horizontal phase out of expected range for pose 18
# Warning: Vertical phase out of expected range for pose 18
# Processed pose 18: 408 corners
# Error processing pose 19: Checkerboard corners not detected for pose 19
# Warning: Horizontal phase out of expected range for pose 20
# Warning: Vertical phase out of expected range for pose 20
# Processed pose 20: 408 corners
# Warning: Horizontal phase out of expected range for pose 21
# Warning: Vertical phase out of expected range for pose 21
# Processed pose 21: 408 corners
# Warning: Horizontal phase out of expected range for pose 22
# Warning: Vertical phase out of expected range for pose 22
# Processed pose 22: 408 corners
# Error processing pose 23: Checkerboard corners not detected for pose 23
# Warning: Horizontal phase out of expected range for pose 24
# Warning: Vertical phase out of expected range for pose 24
# Processed pose 24: 408 corners
# Error processing pose 25: Checkerboard corners not detected for pose 25
# Warning: Horizontal phase out of expected range for pose 26
# Warning: Vertical phase out of expected range for pose 26
# Processed pose 26: 408 corners
# Error processing pose 27: Checkerboard corners not detected for pose 27
# Warning: Horizontal phase out of expected range for pose 28
# Warning: Vertical phase out of expected range for pose 28
# Processed pose 28: 408 corners
# Error processing pose 29: Checkerboard corners not detected for pose 29
# Warning: Horizontal phase out of expected range for pose 30
# Warning: Vertical phase out of expected range for pose 30
# Processed pose 30: 408 corners
#
# Sample Camera-Projector Correspondences (Pose 1, first 5 corners):
# Corner 0: Camera (156.40, 1202.06) -> Projector (-1322.62, 169.02)
# Corner 1: Camera (155.97, 1129.18) -> Projector (-1329.82, 72.68)
# Corner 2: Camera (155.62, 1056.64) -> Projector (-1324.37, -45.88)
# Corner 3: Camera (155.34, 984.82) -> Projector (-1315.40, -168.20)
# Corner 4: Camera (154.99, 913.45) -> Projector (-1317.67, -277.49)

# %%
# projector calibration
criteriaEnd = (cv2.TERM_CRITERIA_EPS + cv2.TERM_CRITERIA_MAX_ITER, 30000, 0.0001)  # Termination criteria for estimateCameraParams
P_ret, P_K_intrinsic, P_dist, P_rvecs, P_tvecs = cv2.calibrateCamera(
    all_obj_points, all_proj_points, (PROJ_COLS, PROJ_ROWS), None, None,
    flags=cv2.CALIB_FIX_K4 + cv2.CALIB_FIX_K5 + cv2.CALIB_FIX_K6,criteria=criteriaEnd
)
print("Projector Intrinsic Matrix:\n", P_K_intrinsic)
print("Distortion Coefficients:\n", P_dist)
print("Projector average error", P_ret)

for i in range(len(all_obj_points)):
    # Ensure inputs are in the correct format
    obj_points = all_obj_points[i]  # Shape: (N, 3)
    rvec = P_rvecs[i]               # Shape: (3,) or (3, 1)
    tvec = P_tvecs[i]               # Shape: (3,) or (3, 1)
    
    # Project 3D points to 2D image points
    imgpoints2, _ = cv2.projectPoints(obj_points, rvec, tvec, P_K_intrinsic, distCoeffs=P_dist)
    
    # Ensure all_proj_points[i] and imgpoints2 have compatible shapes
    observed_points = all_proj_points[i].squeeze()  # Shape: (N, 2)
    projected_points = imgpoints2.squeeze()   # Shape: (N, 2)
    
    # Calculate reprojection error (L2 norm divided by number of points)
    error = cv2.norm(observed_points, projected_points, cv2.NORM_L2) / len(projected_points)
    print(f'pose{i+1} -> {error}')
# Out:
# Projector Intrinsic Matrix:
#  [[ 4.37083652e+03  0.00000000e+00 -3.50159342e+01]
#  [ 0.00000000e+00  4.35027177e+03  5.75230709e+02]
#  [ 0.00000000e+00  0.00000000e+00  1.00000000e+00]]
# Distortion Coefficients:
#  [[ 0.06011574 -0.19146013  0.00337381 -0.00178109  0.32529619]]
# Projector average error 12.773506214114006
# pose1 -> 0.684978234966449
# pose2 -> 0.6531864314249881
# pose3 -> 0.6714459278291494
# pose4 -> 0.6479481065058978
# pose5 -> 0.6043210246013753
# pose6 -> 0.5849689382387385
# pose7 -> 0.6700040100008163
# pose8 -> 0.6988169417944166
# pose9 -> 0.6608822500457188
# pose10 -> 0.6023165822838936
# pose11 -> 0.6315071059532547
# pose12 -> 0.623604675255242
# pose13 -> 0.557208424576815
# pose14 -> 0.589427232472761
# pose15 -> 0.6236418357164533
# pose16 -> 0.59343068942824
# pose17 -> 0.6294579668298936
# pose18 -> 0.6647430728262729
# pose19 -> 0.6022913876836279

# %% [markdown]
# Expression for A

# %% [markdown]
# Question a

# %%
# Function to construct a 3x4 projection matrix
def get_projection_matrix(K, rvec, tvec):
    # Convert rotation vector to rotation matrix
    R, _ = cv2.Rodrigues(rvec)
    # Form [R|T] (3x4 matrix)
    RT = np.hstack((R, tvec.reshape(3, 1)))
    # Compute projection matrix P = K[R|T]
    P = K @ RT
    return P

# Construct projection matrices
P_c = get_projection_matrix(C_K_intrinsic, C_rvecs[0], C_tvecs[0])  # Camera
P_p = get_projection_matrix(P_K_intrinsic, P_rvecs[0], P_tvecs[0])  # Projector

print("Camera projection matrix P_c:")
print(P_c)
print("\nProjector projection matrix P_p:")
print(P_p)
# Out:
# Camera projection matrix P_c:
# [[ 6.63997219e+00  2.00002111e+03  2.30791300e+02  3.76369891e+03]
#  [-1.76270287e+03  1.66999293e+02  8.01878035e+02  3.07782617e+04]
#  [ 1.06554217e-01  2.97595122e-01  9.48727222e-01  2.54606521e+01]]
#
# Projector projection matrix P_p:
# [[-3.80674765e+01  4.37016884e+03 -7.49213571e+01 -7.51362085e+05]
#  [-4.28331830e+03 -2.55812382e+01  9.53039726e+02  1.00722091e+05]
#  [ 8.72860680e-02  9.82538688e-03  9.96134832e-01  5.68885117e+02]]

# %%
# get the previous camera matrices to world matrix and projector to world matrix

import numpy as np

# Example projection matrices (3x4) and image coordinates
# Replace these with your actual data
x_c, y_c = 155.97, 1129.18    # Camera image coordinates
x_p = -1329.82                # Projector image coordinate

# Construct matrix A (3x3)
A = np.array([
    [P_c[0,0] - x_c * P_c[2,0], P_c[0,1] - x_c * P_c[2,1], P_c[0,2] - x_c * P_c[2,2]],
    [P_c[1,0] - y_c * P_c[2,0], P_c[1,1] - y_c * P_c[2,1], P_c[1,2] - y_c * P_c[2,2]],
    [P_p[0,0] - x_p * P_p[2,0], P_p[0,1] - x_p * P_p[2,1], P_p[0,2] - x_p * P_p[2,2]]
])

# Construct vector b (3x1)
b = np.array([
    x_c * P_c[2,3] - P_c[0,3],
    y_c * P_c[2,3] - P_c[1,3],
    x_p * P_p[2,3] - P_p[0,3]
])

# Check if A is invertible (determinant non-zero)
det_A = np.linalg.det(A)
if abs(det_A) < 1e-10:
    print("Warning: Matrix A is singular or nearly singular. Solution may be unreliable.")
else:
    # Solve Ax = b
    try:
        x_hat = np.linalg.solve(A, b)
        print("Solution x_hat = [x_w, y_w, z_w]^T:")
        print(x_hat)
    except np.linalg.LinAlgError:
        print("Error: Could not solve the system. Matrix A may be singular.")

# Verify the solution
print("\nVerification (A * x_hat should equal b):")
print("A * x_hat =", A @ x_hat)
print("b =", b)
# Out:
# Solution x_hat = [x_w, y_w, z_w]^T:
# [ 1.82632439  0.34664743 -5.45275263]
#
# Verification (A * x_hat should equal b):
# A * x_hat = [  207.39901078 -2028.60253348 -5152.72116965]
# b = [  207.39901078 -2028.60253348 -5152.72116965]

# %% [markdown]
# Load David

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
from scipy.ndimage import map_coordinates
# import open3d as o3d

# Projector resolution
PROJ_COLS = 3840
PROJ_ROWS = 2160

# Phase ranges (adjust based on your phase maps)
HORIZ_PHASE_RANGE = 2 * np.pi  # [0, 2π] for horizontal (columns)
VERT_PHASE_RANGE = 1.125 * np.pi  # [0, 1.125π] for vertical (rows)

# Checkerboard size (inner corners, adjust as needed)
CHECKERBOARD = (17, 24)

# Checkerboard square size (in mm, adjust as needed)
SQUARE_SIZE = 15.0  # mm


def compute_phase_map(I0, I1, I2, I3):
    """Compute phase map using four-phase shift algorithm."""
    I0, I1, I2, I3 = [img.astype(float) for img in [I0, I1, I2, I3]]
    numerator = I3 - I1
    denominator = I0 - I2
    phase = np.arctan2(numerator, denominator)
    phase = np.where(phase < 0, phase + 2 * np.pi, phase)  # [0, 2π]
    return phase

def load_phase_images(base_path, pos_num="David"):
    """Load eight phase-shifted images: 1-4 (horizontal), 5-8 (vertical)."""
    images = [cv2.imread(f"{base_path}/{pos_num}_{i+1}.png", cv2.IMREAD_GRAYSCALE) for i in range(8)]
    if any(img is None for img in images):
        raise FileNotFoundError(f"Failed to load phase images from {base_path}")
    return tuple(images[:4]), tuple(images[4:])

def find_projector_pixels(corners, phase_h, phase_v, use_interpolation=False):
    """Map camera coordinates to projector coordinates using phase maps."""
    corners = np.asarray(corners, dtype=np.float32)
    if len(corners.shape) != 3 or corners.shape[1] != 1 or corners.shape[2] != 2:
        raise ValueError(f"Expected corners shape (N, 1, 2), got {corners.shape}")
    
    corners_2d = corners.squeeze(axis=1)
    corner_phases_h = np.zeros(len(corners_2d), dtype=np.float32)
    corner_phases_v = np.zeros(len(corners_2d), dtype=np.float32)
    
    if use_interpolation:
        for i, corner in enumerate(corners_2d):
            x, y = corner  # Subpixel coordinates
            # Use bilinear interpolation to get phase values
            corner_phases_h[i] = map_coordinates(phase_h, [[y], [x]], order=1, mode='nearest')
            corner_phases_v[i] = map_coordinates(phase_v, [[y], [x]], order=1, mode='nearest')
    else:
        for i, corner in enumerate(corners_2d):
            x, y = int(corner[0]), int(corner[1])
            corner_phases_h[i] = phase_h[y, x]
            corner_phases_v[i] = phase_v[y, x]
    
    proj_cols = (corner_phases_h / HORIZ_PHASE_RANGE) * PROJ_COLS
    proj_rows = (corner_phases_v / VERT_PHASE_RANGE) * PROJ_ROWS
    proj_pixels = np.stack((proj_cols, proj_rows), axis=-1).reshape(-1, 1, 2)
    return proj_pixels

def shift_phase_jump(phase_map, offset):
    """Shift phase jump by adding offset and rewrapping."""
    return np.angle(np.exp(1j * (phase_map + offset)))

def get_checkerboard_world_points(checkerboard, square_size):
    """Generate 3D world points for checkerboard corners."""
    rows, cols = checkerboard
    objp = np.zeros((rows * cols, 3), np.float32)
    objp[:, :2] = np.mgrid[0:rows, 0:cols].T.reshape(-1, 2) * square_size
    return objp



def getDavidWorldPixels(gray_undist, mask_path="Data/DavidMask.png", plot=True):
    """
    Reads a grayscale image and mask, returns x,y coordinates where mask intensity is 1.
    Plots the masked image using imshow, with optional scatter of active coordinates.
    Coordinates are ordered from top-left to bottom-right.
    
    Args:
        gray_undist: Grayscale image (numpy array)
        mask_path: Path to mask image (default: "Data/DavidMask.png")
        plot: If True, display the masked image and active coordinates (default: True)
    
    Returns:
        numpy array of shape (N, 1, 2) containing [x, y] coordinates
    """
    # Read mask image
    mask = cv2.imread(mask_path, cv2.IMREAD_GRAYSCALE)
    
        # Count pixels with intensity 255
    num_255_pixels = np.sum(mask == 255)
    print(f"Number of pixels with intensity 255 in mask: {num_255_pixels}")
    # Ensure mask and input image have same dimensions
    if mask.shape != gray_undist.shape:
        raise ValueError("Mask and input image must have the same dimensions")
    
    # Create binary mask (assuming mask values are 0 or 255)
    mask_binary = (mask == 255).astype(np.uint8)
    
    # Apply mask to grayscale image
    masked_image = cv2.bitwise_and(gray_undist, gray_undist, mask=mask_binary)
    
    # Find coordinates where mask intensity is 1
    y, x = np.nonzero(mask_binary)
    
    # Combine into [x, y] pairs
    coords = np.column_stack((x, y))
    # Sort coordinates from top-left to bottom-right
    coords = coords[np.lexsort((coords[:, 0], coords[:, 1]))]
    # Reshape to (N, 1, 2)
    coords_reshaped = coords[:, np.newaxis, :]
    
    # Plot the masked image
    if plot:
        plt.figure(figsize=(8, 6))
        plt.imshow(masked_image, cmap='gray')
        # Optionally overlay coordinates as scatter points
        # plt.scatter(coords[:, 0], coords[:, 1], c='red', s=1, alpha=0.5, label='Active Pixels')
        plt.title('Masked Image with Active Pixels')
        plt.xlabel('Pixel Column (x)')
        plt.ylabel('Pixel Row (y)')
        plt.legend()
        plt.tight_layout()
        plt.show()
    
    return coords_reshaped

def process_pose(pose_num, base_path_no_pattern, base_path_pattern, camera_matrix, dist_coeffs, newcameramtx):
    """Process a single checkerboard pose to find camera-projector correspondences."""
    david_img = cv2.imread(f"{base_path_no_pattern}/David.png",cv2.IMREAD_GRAYSCALE)
    if david_img is None:
        raise FileNotFoundError(f"Checkerboard image David.png not found")

    
    # get david world pixels in mask 
    David_pixels = getDavidWorldPixels(david_img,mask_path ="Data/DavidMask.png")
    # print(David_pixels)
    
    (h_I0, h_I1, h_I2, h_I3), (v_I0, v_I1, v_I2, v_I3) = load_phase_images(base_path_pattern)
    h_I0 = cv2.undistort(h_I0, camera_matrix, dist_coeffs, None, newcameramtx)
    h_I1 = cv2.undistort(h_I1, camera_matrix, dist_coeffs, None, newcameramtx)
    h_I2 = cv2.undistort(h_I2, camera_matrix, dist_coeffs, None, newcameramtx)
    h_I3 = cv2.undistort(h_I3, camera_matrix, dist_coeffs, None, newcameramtx)
    v_I0 = cv2.undistort(v_I0, camera_matrix, dist_coeffs, None, newcameramtx)
    v_I1 = cv2.undistort(v_I1, camera_matrix, dist_coeffs, None, newcameramtx)
    v_I2 = cv2.undistort(v_I2, camera_matrix, dist_coeffs, None, newcameramtx)
    v_I3 = cv2.undistort(v_I3, camera_matrix, dist_coeffs, None, newcameramtx)
    
    phase_h = compute_phase_map(h_I0, h_I1, h_I2, h_I3)
    phase_v = compute_phase_map(v_I0, v_I1, v_I2, v_I3)
    
    h_offset, v_offset = -1.6, -1.8
    new_horizontal_phase = shift_phase_jump(phase_h, h_offset)
    new_vertical_phase = shift_phase_jump(phase_v, v_offset)

        # Visualize phase maps 
    plt.figure(figsize=(12, 5))
    plt.subplot(1, 2, 1)
    plt.imshow(new_horizontal_phase, cmap='viridis')
    plt.title('Horizontal Phase Map')
    plt.colorbar(label='Phase (radians)')
    plt.subplot(1, 2, 2)
    plt.imshow(new_vertical_phase, cmap='viridis')
    plt.title('Vertical Phase Map')
    plt.colorbar(label='Phase (radians)')
    plt.tight_layout()
    plt.show()
    

    # Find projector coordinates for David pixels
    proj_points = find_projector_pixels(David_pixels, new_horizontal_phase, new_vertical_phase, use_interpolation=True)
    
    # Placeholder for checkerboard points (since David doesn't use checkerboard)
    CHECKERBOARD = (17, 24)  # Dummy value, not used for David
    SQUARE_SIZE = 1.0  # Dummy value, not used for David
    obj_points = get_checkerboard_world_points(CHECKERBOARD, SQUARE_SIZE)
    cam_points = David_pixels.squeeze()  # Use David pixels as camera points
    
    return obj_points, cam_points, proj_points, new_horizontal_phase, new_vertical_phase


def compute_point_cloud(camera_phase_h, camera_phase_v, P_c, P_p, cam_height, cam_width, proj_cols, proj_rows, David_pixels=None):
    """Compute 3D point cloud from phase maps using A and b matrix method, filtered by David mask."""
    points_3d = []
    
    if David_pixels is not None:
        # Use only masked pixels
        corners_2d = David_pixels.squeeze()  # Shape: (N, 2)
        for x_c, y_c in corners_2d:
            x_c, y_c = int(x_c), int(y_c)  # Convert to integer indices
            if (0 <= y_c < cam_height and 0 <= x_c < cam_width):
                # Projector coordinates
                x_p = (camera_phase_h[y_c, x_c] / HORIZ_PHASE_RANGE) * (proj_cols - 1)
                y_p = (camera_phase_v[y_c, x_c] / VERT_PHASE_RANGE) * (proj_rows - 1)
                
                # Construct matrix A (3x3)
                A = np.array([
                    [P_c[0,0] - x_c * P_c[2,0], P_c[0,1] - x_c * P_c[2,1], P_c[0,2] - x_c * P_c[2,2]],
                    [P_c[1,0] - y_c * P_c[2,0], P_c[1,1] - y_c * P_c[2,1], P_c[1,2] - y_c * P_c[2,2]],
                    [P_p[0,0] - x_p * P_p[2,0], P_p[0,1] - x_p * P_p[2,1], P_p[0,2] - x_p * P_p[2,2]]
                ])
                
                # Construct vector b (3x1)
                b = np.array([
                    x_c * P_c[2,3] - P_c[0,3],
                    y_c * P_c[2,3] - P_c[1,3],
                    x_p * P_p[2,3] - P_p[0,3]
                ])
                
                # Solve Ax = b
                det_A = np.linalg.det(A)
                if abs(det_A) > 1e-6:  # Relaxed determinant threshold
                    try:
                        x_hat = np.linalg.solve(A, b)
                        points_3d.append(x_hat)
                    except np.linalg.LinAlgError:
                        continue  # Skip points where the system can't be solved
                else:
                    continue  # Skip singular matrices
    else:
        # Fallback to original full image processing (for debugging)
        for y in range(cam_height):
            for x in range(cam_width):
                x_p = (camera_phase_h[y, x] / HORIZ_PHASE_RANGE) * (proj_cols - 1)
                y_p = (camera_phase_v[y, x] / VERT_PHASE_RANGE) * (proj_rows - 1)
                
                A = np.array([
                    [P_c[0,0] - x * P_c[2,0], P_c[0,1] - x * P_c[2,1], P_c[0,2] - x * P_c[2,2]],
                    [P_c[1,0] - y * P_c[2,0], P_c[1,1] - y * P_c[2,1], P_c[1,2] - y * P_c[2,2]],
                    [P_p[0,0] - x_p * P_p[2,0], P_p[0,1] - x_p * P_p[2,1], P_p[0,2] - x_p * P_p[2,2]]
                ])
                
                b = np.array([
                    x * P_c[2,3] - P_c[0,3],
                    y * P_c[2,3] - P_c[1,3],
                    x_p * P_p[2,3] - P_p[0,3]
                ])
                
                det_A = np.linalg.det(A)
                if abs(det_A) > 1e-6:
                    try:
                        x_hat = np.linalg.solve(A, b)
                        points_3d.append(x_hat)
                    except np.linalg.LinAlgError:
                        continue

    points_3d = np.array(points_3d)  # Shape: (N, 3)
    return points_3d



def main():
    base_path_no_pattern = "Data/Reconstruction/NoPattern/"
    base_path_pattern = "Data/Reconstruction/Patterns/David"
    

    num_poses = 1
    all_obj_points, all_cam_points, all_proj_points = [], [], []
    cam_width = 0
    cam_height = 0
    phase_h = None
    phase_v = None

    for pose_num in range(1, num_poses + 1):
        obj_points, cam_points, proj_points, ph, pv = process_pose(
            pose_num, base_path_no_pattern, base_path_pattern,
            C_K_intrinsic, dist_coeffs1, newcameramtx
        )
        all_obj_points.append(obj_points)
        all_cam_points.append(cam_points)
        all_proj_points.append(proj_points)
        print(f"Processed pose {pose_num}: {len(cam_points)} corners")
        print(ph.shape)

        cam_height, cam_width = ph.shape
        phase_h = ph  # Store the last successful phase_h
        phase_v = pv  # Store the last successful phase_v

    # Compute point cloud using the last successful phase maps
    if phase_h is not None and phase_v is not None:
        pcd = compute_point_cloud(phase_h, phase_v, P_c, P_p, cam_height, cam_width, PROJ_COLS, PROJ_ROWS, David_pixels=cam_points.reshape(-1, 1, 2))
        print(pcd)
        # Visualize point cloud
        # o3d.visualization.draw_geometries([pcd])
        # Create 3D scatter plot
        fig = plt.figure(figsize=(10, 8))
        ax = fig.add_subplot(111, projection='3d')
        ax.scatter(pcd[:, 0], pcd[:, 1], pcd[:, 2], c='b', marker='o', s=1)
        ax.set_title('3D Point Cloud')
        ax.set_xlabel('X')
        ax.set_ylabel('Y')
        ax.set_zlabel('Z')
        plt.show()
    else:
        print("No valid phase maps processed to compute point cloud.")
        
    # Visualize point cloud
    # o3d.visualization.draw_geometries([pcd])
    
    return all_obj_points, all_cam_points, all_proj_points, pcd

if __name__ == "__main__":
    all_obj_points, all_cam_points, all_proj_points, pcd = main()
# Out:
# Number of pixels with intensity 255 in mask: 254396
# /var/folders/6q/b1f95jp528qg7gf5zww7z9h80000gn/T/ipykernel_15997/4258464702.py:127: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
# /var/folders/6q/b1f95jp528qg7gf5zww7z9h80000gn/T/ipykernel_15997/4258464702.py:52: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   corner_phases_h[i] = map_coordinates(phase_h, [[y], [x]], order=1, mode='nearest')
# /var/folders/6q/b1f95jp528qg7gf5zww7z9h80000gn/T/ipykernel_15997/4258464702.py:53: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   corner_phases_v[i] = map_coordinates(phase_v, [[y], [x]], order=1, mode='nearest')
# Processed pose 1: 254396 corners
# (1240, 1616)
# [[139.06205677 229.60902619 457.83427742]
#  [139.25094017 230.23440259 458.47776094]
#  [138.09728052 228.56941966 454.26087377]
#  ...
#  [-91.20789491 162.71935885 445.64959913]
#  [-90.43806548 160.29562493 441.00818009]
#  [-94.62942937 167.52340535 461.47150418]]

# %% [markdown]
# Export to ply

# %%
def save_ply(points, filename="point_cloud.ply"):
    """
    Saves 3D points to a PLY file in ASCII format.

    Parameters:
    - points: np.ndarray of shape (N, 3), 3D points with X, Y, Z coordinates (mm)
    - filename: Output PLY file path
    """
    num_points = points.shape[0]

    # Write PLY header
    header = f"""ply
format ascii 1.0
element vertex {num_points}
property float x
property float y
property float z
end_header
"""

    # Write points
    with open(filename, 'w') as f:
        f.write(header)
        for point in points:
            f.write(f"{point[0]} {point[1]} {point[2]}\n")

    print(f"PLY file saved to {filename}")

save_ply(pcd, filename="./David_point_cloud.ply")
# Out:
# PLY file saved to ./David_point_cloud.ply
